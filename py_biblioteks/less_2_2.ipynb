# %% [markdown]
# <a href="https://colab.research.google.com/github/roman-mikhaylov/repo_sinergiya/blob/main/less_2_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задание 2.2**
# Создать свой собственный объект Series и DataFrame. Открыть любой CSV-файл, полученный из интернета.
#  Для этого необходимо выбрать свой собственный датасет на ресурсе Kaggle.

# %%
import pandas as pd

# %%
series = pd.Series(["нюша","бараш","крош","корпатыч","пин"])
series
# Out:
# 0        нюша
# 1       бараш
# 2        крош
# 3    корпатыч
# 4         пин
# dtype: object

# %%
df = pd.DataFrame({"name": ["нюша","бараш","крош","корпатыч","пин"], "color":["pink","purple","blue","brown","grey"]})
df
# Out:
#        name   color
# 0      нюша    pink
# 1     бараш  purple
# 2      крош    blue
# 3  корпатыч   brown
# 4       пин    grey

# %%
df = pd.DataFrame({ "color":["pink","purple","blue","brown","grey"]}, index = ["нюша","бараш","крош","корпатыч","пин"])
df
# Out:
#            color
# нюша        pink
# бараш     purple
# крош        blue
# корпатыч   brown
# пин         grey

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Student Stress Factors_for_less_2_1_utf8_1.csv")
df.head()
# Out:
#              Timestamp  Kindly Rate your Sleep Quality  \
# 0  27/10/2023 21:54:15                               3
# 1  28/10/2023 12:24:40                               4
# 2  28/10/2023 12:24:51                               2
# 3  28/10/2023 12:26:11                               3
# 4  28/10/2023 12:26:45                               2
#
#    How many times a week do you suffer headaches  \
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              2
# 4                                              3
#
#    How would you rate you academic performance  \
# 0                                            3
# 1                                            2
# 2                                            2
# 3                                            3
# 4                                            1
#
#    how would you rate your study load  \
# ...
