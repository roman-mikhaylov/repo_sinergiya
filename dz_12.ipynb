# %% [markdown]
# <a href="https://colab.research.google.com/github/roman-mikhaylov/repo_sinergiya/blob/main/dz_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задание №12: Визуализации. Кейсы по применению визуализаций.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# делаем словарь = список слов.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# далее очищаем текст с заменой на пробелы
# text = text.replace('\n', ' ') ... lover()
# затем убираем пробелы
# text_splited = text.split(" ")
# счтаем количество слов и сортируем

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# далее легимитазация по языку
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# после всех действий над словарём получаем подтверждение закона Ципфа
# (нам нужна частотность ведь)
# Зако́н Ци́пфа («ранг—частотность») — эмпирическая закономерность распределения частотности слов естественного языка: если все слова языка (или просто достаточно длинного текста) упорядочить по убыванию частотности их использования, то частотность n-го слова в таком списке окажется приблизительно обратно пропорциональной его порядковому номеру n (так называемому рангу этого слова, см. шкала порядка). Например, второе по используемости слово встречается примерно в два раза реже, чем первое, третье — в три раза реже, чем первое, и так далее.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# наш вариант

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **студенты**

# %% [markdown]
# база
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# вид
# ![image.png](data:image/png;base64,...)

# %%
переводим на булевские значения "согласен/не согласен"и т.д

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# и убираем незначимые значения столбцами

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# в итоге
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# проверка гепотеза по влиянию ГТО на поступление
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# и проверка обратной гепотизы
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ГТО не влияет)

# %% [markdown]
# инструмент Qwery
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# корреляция по математикам M1 и M2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# нет ясности. делаем бокссплот
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# корреляцию между проверяем
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# можно отрисовать средние по боксплотам
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# вывод - есть корреляция. почти прямая

# %% [markdown]
# сравним звисимость между физикой и одной из математик (М2)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# блоксплоты
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ну и далее...
