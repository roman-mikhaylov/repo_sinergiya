# %% [markdown]
# <a href="https://colab.research.google.com/github/roman-mikhaylov/repo_sinergiya/blob/main/dz_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задание №14: Библиотека Plotly.**

# %% [markdown]
# 1 Что позволяет делать библиотека Plotly?
#
#  Библиотека Plotly в Python делает интерактивные графики онлайн и позволяет нам
# сохранять их в автономном режиме, если это необходимо.

# %%
import plotly
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = px.data.iris()
fig = px.scatter_3d(df, x = 'sepal_width', y = 'sepal_length', z = 'petal_width', color = 'species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 2 Назовите основные преимущества этой библиотеки перед аналогичными?
#
#  По умолчанию он интерактивен. Диаграммы не сохраняются как изображения, а
# сериализуются как JSON, что делает их открытыми для чтения с помощью R, MATLAB,
# Julia и других. Вектор экспорта для печати и публикации. Легко манипулировать и
# встраивать в Интернет.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3 Какие диаграммы позволяет рисовать данная библиотека?
#
# 3 График OHLC
#
# График временных рядов
# Финансовые графики
#
# Контурные графики
#
# Коробчатые графики
#
# Линия и точечная диаграмма
#
# Точечная диаграмма
#
# 3D

# %% [markdown]
# **конспект**

# %%
import plotly
import plotly.express as px
import matplotlib.pyplot as plt

# %%
"""
отрисовка линии
"""
#plt.figure(figsize=(3,6))
fig = px.line(x=[1,2,3], y=[1,2,3])
fig.show()

# %%
# визуализация dataset penguins
import seaborn as sns
import matplotlib.pyplot as plt
penguins = sns.load_dataset('penguins')
penguins

# %%
type(penguins)

# %%
fig = px.line(penguins, x='species', y='bill_depth_mm')
fig.show()

# %%
fig = px.scatter(penguins, x='body_mass_g', y='bill_depth_mm')
fig.show()

# %%
fig = px.bar(penguins, x='body_mass_g', y='bill_depth_mm')
fig.show()

# %%
fig = px.histogram(penguins, x='body_mass_g', y='bill_depth_mm')
fig.show()

# %%
#меняем Nan на среднее  в bill_depth_mm -пригодиться дальше
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())
penguins['bill_depth_mm']

# %%
fig = px.scatter(penguins, x="species", y="body_mass_g", size="bill_depth_mm", color="species")
fig.show()

# %%
import numpy as np
penguins_Biscoe = penguins[penguins.island == 'Biscoe']
penguins_Biscoe['count'] = np.ones_like(penguins_Biscoe.species)

penguins_Torgersen = penguins[penguins.island == 'Torgersen']
penguins_Torgersen['count'] = np.ones_like(penguins_Torgersen.species)

penguins_Dream = penguins[penguins.island == 'Dream']
penguins_Dream['count'] = np.ones_like(penguins_Dream.species)

# %%
fig = px.pie(penguins_Biscoe, values = "count", names="species")
fig.show()

# %%
fig = px.pie(penguins_Biscoe, values = "count", names="species", hole = 0.3)
fig.show()

# %% [markdown]
# ксогда необходимо совместить на одной визуализации

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# другие датасеты

# %%
df = px.data.tips()
df

# %%
fig = px.box(df, x='day', y='total_bill')
fig.show()

# %% [markdown]
# контрплоты и тепловые карты

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3D**

# %%
df = px.data.iris()
df

# %%
sns.pairplot(df[['sepal_length','sepal_width', 'petal_length', 'petal_width', 'species' ]], hue = 'species')

# %%
fig = px.scatter_3d(df, x = 'sepal_width', y = 'sepal_length', z = 'petal_width', color = 'species')

# sepal_length','sepal_width', 'petal_length', 'petal_width', 'species'

fig.show()
