# %% [markdown]
# <a href="https://colab.research.google.com/github/roman-mikhaylov/repo_sinergiya/blob/main/dz_d17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание №17- 18: Визуализации. Кейсы по применению визуализаций

# %% [markdown]
# пример с ММВБ

# %% [markdown]
# берем "стакан"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# отделяем нужные данные
# ![image.png](data:image/png;base64,...)
# получаем
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# определяем частоту ликвидности ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# выделяем 30 % самых торгуемых акций, их количество, по иммитентам

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# смотрим на них

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# строим график по ним ![image.png](data:image/png;base64,...)

# %% [markdown]
# 30% в графике
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# и создадим отдельные датасеты по best_companies, поместив их в словарь![image.png](data:image/png;base64,...)

# %% [markdown]
# **посмотрим на СБЕР**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# заменим в BYSELL значения на +1 и -1 и добавим dir_vol - направление покупки\продажи
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# смотрим на то, чо получилось в итоге
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# посмотрим на куммулятивный обьем. Добавим "cumvol" как сумму по "dir_vol"  и равномерную сетку  по заявкам (уходим от времени)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# теперь по исполненным (action = 1). совместим оба графика ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# главный вывод - необходимо время учитывать

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# в качестве индекса теперь используем время

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# обобщаем на 15 секудном интервале. цену среднюю берем. веса не берем
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# график
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# возьмем в качестве X  длину датасета
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  совсем не нормальное распределение)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# сделаем дляостальных тикеров
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# точнее для 3-х
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# далее преобразуем схожим оббразом топ 20
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# а теперь корреляции
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# оценим визуально распределения
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# совсем не нормальное распределение - данных маловато)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# и даже при принудительной нормализации
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
